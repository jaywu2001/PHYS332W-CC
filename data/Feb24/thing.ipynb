# %%
import matplotlib.pyplot as plt
import numpy as np
import bifurcation as bf

# %%
datastrings = []
for i in range(1,10):
    string = "data/SDS0000"+str(i)+".bin"
    datastrings.append(string)
for i in range(10,100):
    string = "data/SDS000"+str(i)+".bin"
    datastrings.append(string)
for i in range(100,488):
    string = "data/SDS00"+str(i)+".bin"
    datastrings.append(string)
plt.figure(figsize=(16,9),dpi=200)
for i in range(0,487):
    data = bf.GETAMPLITUDES(datastrings[i])
    plt.plot(np.ones(data.size)*(50.0 + (i/10.0)), data, 'k.', markersize=1)
plt.ylabel(r"Amplitude (V)")
plt.xlabel(r"$R_v$ (k$\Omega$)")
plt.title(r"Amplitude (V) vs. $R_v$ (k$\Omega$)")
plt.show()

# %%
data = bf.GETAMPLITUDES("SDS00200.bin")

# %%
data = bf.GETAMPLITUDES("SDS00200.bin")
plt.plot(np.ones(data.size)*(50.0 + (1/10.0)), data, 'k.', markersize=1)
plt.ylabel(r"Amplitude (V)")
plt.xlabel(r"$R_v$ (k$\Omega$)")
plt.title(r"Amplitude (V) vs. $R_v$ (k$\Omega$)")
plt.show()
