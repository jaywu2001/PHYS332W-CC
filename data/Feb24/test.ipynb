# %%
from parse import data as parse
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks as fp
import scipy.fft as fft
import bifurcation as BF

# %%
datastrings = []
plt.figure(figsize=(8,4.5),dpi=150)
for i in range(80,100):
    string = "data/SDS000"+str(i)+".bin"
    datastrings.append(string)
for i in range(100,115):
    string = "data/SDS00"+str(i)+".bin"
    datastrings.append(string)
for i in range(0,len(datastrings)):
    data = BF.GETAMPLITUDES(datastrings[i])
    plt.plot(np.ones(data.size)*(50.0 + ((i+79)/10.0)), data, 'k.', markersize=1)
plt.ylabel(r"Amplitude (V)")
plt.xlabel(r"$R_v$ (k$\Omega$)")
plt.title(r"Amplitude (V) vs. $R_v$ (k$\Omega$)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       8     datastrings.append(string)
#       9 for i in range(0,len(datastrings)):
# ---> 10     data = BF.GETAMPLITUDES(datastrings[i])
#      11     plt.plot(np.ones(data.size)*(50.0 + ((i+79)/10.0)), data, 'k.', markersize=1)
#      12 plt.ylabel(r"Amplitude (V)")
#
# File /mnt/c/Users/theic/Downloads/CLASSES/PHYS 332W/PHYS332W-CC/data/Feb24/bifurcation.py:67, in GETAMPLITUDES(FILEPATH)
#      65 temp = np.argwhere((FREQS<3.7)&(FREQS>1.5))
#      66 FREQS = FREQS[temp].ravel()
# ---> 67 FFT = np.log10(np.abs(fft.rfft(CH1))[temp]).ravel()
#      68 temp = fp(FFT,prominence=1)[0]
#      69 FREQS = 10**(FREQS[temp])
#
# File ~/.local/lib/python3.10/site-packages/scipy/fft/_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      26 if fn is None:
#      27     return NotImplemented
# ---> 28 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/scipy/fft/_basic_backend.py:74, in rfft(x, n, axis, norm, overwrite_x, workers, plan)
#      72 def rfft(x, n=None, axis=-1, norm=None,
#      73          overwrite_x=False, workers=None, *, plan=None):
# ---> 74     return _execute_1D('rfft', _pocketfft.rfft, x, n=n, axis=axis, norm=norm,
#      75                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#
# File ~/.local/lib/python3.10/site-packages/scipy/fft/_basic_backend.py:29, in _execute_1D(func_str, pocketfft_func, x, n, axis, norm, overwrite_x, workers, plan)
#      27 if is_numpy(xp):
#      28     x = np.asarray(x)
# ---> 29     return pocketfft_func(x, n=n, axis=axis, norm=norm,
#      30                           overwrite_x=overwrite_x, workers=workers, plan=plan)
#      32 norm = _validate_fft_args(workers, plan, norm)
#      33 if hasattr(xp, 'fft'):
#
# File ~/.local/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py:61, in r2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      58     raise ValueError(f"invalid number of data points ({tmp.shape[axis]}) specified")
#      60 # Note: overwrite_x is not utilised
# ---> 61 return pfft.r2c(tmp, (axis,), forward, norm, None, workers)
#
# KeyboardInterrupt:

# %%
from parse import data as parse
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks as fp
import scipy.fft as fft
import bifurcation as BF

# %%
ch1,ch2,t = parse(open("SDS00082.bin", "rb"))
plt.plot(t,ch2)
plt.show()
plt.plot(t,ch1)
plt.show()

# %%
DATA = BF.GETAMPLITUDES("SDS00082.bin")
plt.plot(np.ones(len(DATA))*50,DATA,'k.')
plt.show()
