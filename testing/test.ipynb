# %%
from parse import data as parse
import matplotlib.pyplot as plt
file = open("SDS00187.bin","rb")
ch1,ch2,t = parse(file)

# %%
plt.figure(figsize=(8,4.5),dpi=100)
plt.plot(t,ch1)
plt.show()
# plt.figure(figsize=(8,4.5),dpi=100)
# plt.plot(t,ch2)
# plt.show()
# plt.figure(figsize=(8,4.5),dpi=100)
# plt.plot(ch2,ch1)
# plt.show()
