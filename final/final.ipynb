# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import chaoticPackage as CC
import matplotlib.gridspec as gridspec
from scipy.signal import find_peaks as fp
import sim as sim

# %%
eRv,eData = CC.unpack("bifurcation.bin")
sRv,sData = CC.unpack("simulated.bin")

# %%
fig,plts = plt.subplots(ncols=1,nrows=3,tight_layout=1)
fig.set_size_inches((5,9))
plts[0].plot(eRv,eData,'k.',markersize=1.2,alpha=0.5)
plts[0].set_xlim([50,150])
plts[0].set_ylabel(r"$x$ (V)")
plts[0].set_ylim([0,1.5])
plts[0].text(60,1.25,"Experimental")
plts[1].plot(sRv,sData,'k.',markersize=1.2,alpha=0.7)
plts[1].set_xlim([50,150])
plts[1].set_ylabel(r"$x$ (V)")
plts[1].set_ylim([0,1.5])
plts[1].text(60,1.25,"Simulated")
plts[2].plot(eRv,eData,'k.',markersize=1.2,alpha=0.7)
plts[2].plot(sRv,sData,'r.',markersize=1.2,alpha=0.1)
plts[2].set_xlim([50,150])
plts[2].set_ylabel(r"$x$ (V)")
plts[2].set_ylim([0,1.5])
plts[2].text(60,1.25,"Superimposed")
fig.supxlabel(r"$R_v$ (k$\Omega$)")
# plt.figtext(0.05,0.95,"A",size=35,weight="bold")
plt.savefig("bifurcation.pdf",dpi='figure',format='pdf')
plt.show()

# %%
fig1, plts = plt.subplots(ncols=1,nrows=5,tight_layout=1)
fig1.set_size_inches((6,10))
fig1.supylabel(r"Normalized Amplitude ($V$)")
fig1.supxlabel(r"Time (ms)")

ch1,ch2,t = CC.getSmoothData("DATA/SDS00001.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
t1,t2,t3 = sim.simulate(50e3)
t2 += np.abs(min(t2))
t2 /= max(t2)
x = 2810
plts[0].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[0].plot(t[temp]*1e3, ch1[temp], 'go')
plts[0].plot(t[:50000]*1e3,t2[x:x+50000],'r')
plts[0].set_xlim([0,3])
plts[0].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00120.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
t1,t2,t3 = sim.simulate(62e3)
t2 += np.abs(min(t2))
t2 /= max(t2)
x = 2100
plts[1].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[1].plot(t[temp]*1e3, ch1[temp], 'go')
plts[1].plot(t[:50000]*1e3,t2[x:x+50000],'r')
plts[1].set_xlim([0,3])
plts[1].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00211.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
t1,t2,t3 = sim.simulate(71e3)
t2 += np.abs(min(t2))
t2 /= max(t2)
x = 7600
plts[2].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[2].plot(t[temp]*1e3, ch1[temp], 'go')
plts[2].plot(t[:50000]*1e3,t2[x:x+50000],'r')
plts[2].set_xlim([0,3])
plts[2].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00261.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
t1,t2,t3 = sim.simulate(76e3)
t2 += np.abs(min(t2))
t2 /= max(t2)
x = 60000
plts[3].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[3].plot(t[temp]*1e3, ch1[temp], 'go')
plts[3].plot(t[:50000]*1e3,t2[x:x+50000],'r')
plts[3].set_xlim([0,3])
plts[3].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00481.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
t1,t2,t3 = sim.simulate(98e3)
t2 += np.abs(min(t2))
t2 /= max(t2)
x = 76500
plts[4].plot(t[:50000]*1e3,ch1[x:x+50000],'k.')
plts[4].plot(t[temp]*1e3, ch1[temp], 'go')
plts[4].plot(t[:50000]*1e3,t2[:50000],'r')
plts[4].set_xlim([0,3])
plts[4].set_ylim([-0.05,1.1])
plt.figtext(0.95,0.91,"(a)",size=15)
plt.figtext(0.95,0.72,"(b)",size=15)
plt.figtext(0.95,0.52,"(c)",size=15)
plt.figtext(0.95,0.33,"(d)",size=15)
plt.figtext(0.95,0.14,"(e)",size=15)
# plt.savefig("waves.pdf",dpi='figure',format='pdf')
plt.show()

# %%
fig1, plts = plt.subplots(ncols=1,nrows=5,tight_layout=1)
fig1.set_size_inches((6,10))
fig1.supylabel(r"Normalized Amplitude ($V$)")
fig1.supxlabel(r"Time (ms)")

ch1,ch2,t = CC.getSmoothData("DATA/SDS00001.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
plts[0].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[0].plot(t[temp]*1e3, ch1[temp], 'ro')
plts[0].set_xlim([0,3])
plts[0].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00120.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
plts[1].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[1].plot(t[temp]*1e3, ch1[temp], 'ro')
plts[1].set_xlim([0,3])
plts[1].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00211.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
plts[2].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[2].plot(t[temp]*1e3, ch1[temp], 'ro')
plts[2].set_xlim([0,3])
plts[2].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00261.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
plts[3].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[3].plot(t[temp]*1e3, ch1[temp], 'ro')
plts[3].set_xlim([0,3])
plts[3].set_ylim([-0.05,1.1])

ch1,ch2,t = CC.getSmoothData("DATA/SDS00481.bin")
ch1 += np.abs(min(ch1))
ch1 /= max(ch1)
temp = fp(ch1)[0]
plts[4].plot(t[:50000]*1e3,ch1[:50000],'k.')
plts[4].plot(t[temp]*1e3, ch1[temp], 'ro')
plts[4].set_xlim([0,3])
plts[4].set_ylim([-0.05,1.1])
plt.figtext(0.95,0.91,"(a)",size=15)
plt.figtext(0.95,0.72,"(b)",size=15)
plt.figtext(0.95,0.52,"(c)",size=15)
plt.figtext(0.95,0.33,"(d)",size=15)
plt.figtext(0.95,0.14,"(e)",size=15)
plt.savefig("peaks.pdf",dpi='figure',format='pdf')
plt.show()

# %%
tfiles = ['SDS00001.bin','SDS00120.bin','SDS00211.bin','SDS00261.bin','SDS00481.bin']
tfiles = ["DATA/" + x for x in tfiles]
ch1data = []
ch2data = []
tdata = []
for i in range(5):
    t1,t2,t3 = CC.getSmoothData(tfiles[i])
    ch1data.append(t1)
    ch2data.append(t2)
    tdata.append(t3)
    ch1data[i] += np.abs(min(ch1data[i]))
    ch1data[i] /= max(ch1data[i])
    ch2data[i] += np.abs(min(ch2data[i]))
    ch2data[i] /= max(ch2data[i])

# %%
tfiles = ['SDS00001.bin','SDS00120.bin','SDS00211.bin','SDS00261.bin','SDS00481.bin']
tfiles = ["DATA/" + x for x in tfiles]
fig1, f1plts = plt.subplots(ncols=1,nrows=5,tight_layout=1)
fig1.set_size_inches((6,8))
fig1.supxlabel(r"Frequency [$10^x$] (Hz)")
fig1.supylabel(r"Magnitude [$10^y$]")
freq1,fft1 = CC.getSpectrum(tfiles[0])
f1plts[0].plot(freq1,fft1,'k')
f1plts[0].text(1.5,-1,r"$R_v$ = 50.0k$\Omega$")
f1plts[0].set_ylim([-2,6])
f1plts[0].set_xlim([1,6])
f1plts[0].set_yticks(np.arange(-1,6,2))
f1plts[0].text(1.1,-1,"(a)",size=15)
freq1,fft1 = CC.getSpectrum(tfiles[1])
f1plts[1].plot(freq1,fft1,'k')
f1plts[1].text(1.5,-1,r"$R_v$ = 62.0k$\Omega$")
f1plts[1].set_ylim([-2,6])
f1plts[1].set_xlim([1,6])
f1plts[1].set_yticks(np.arange(-1,6,2))
f1plts[1].text(1.1,-1,"(b)",size=15)
freq1,fft1 = CC.getSpectrum(tfiles[2])
f1plts[2].plot(freq1,fft1,'k')
f1plts[2].text(1.5,-1,r"$R_v$ = 71.0k$\Omega$")
f1plts[2].set_ylim([-2,6])
f1plts[2].set_xlim([1,6])
f1plts[2].set_yticks(np.arange(-1,6,2))
f1plts[2].text(1.1,-1,"(c)",size=15)
freq1,fft1 = CC.getSpectrum(tfiles[3])
f1plts[3].plot(freq1,fft1,'k')
f1plts[3].text(1.5,-1,r"$R_v$ = 76.0k$\Omega$")
f1plts[3].set_ylim([-2,6])
f1plts[3].set_xlim([1,6])
f1plts[3].set_yticks(np.arange(-1,6,2))
f1plts[3].text(1.1,-1,"(d)",size=15)
freq1,fft1 = CC.getSpectrum(tfiles[4])
f1plts[4].plot(freq1,fft1,'k')
f1plts[4].text(1.5,-1,r"$R_v$ = 98.0k$\Omega$")
f1plts[4].set_ylim([-2,6])
f1plts[4].set_xlim([1,6])
f1plts[4].set_yticks(np.arange(-1,6,2))
f1plts[4].text(1.1,-1,"(e)",size=15)
plt.savefig("powerSpectralDensity.pdf",dpi='figure',format='pdf')
plt.show()

# %%
tfiles = ['SDS00001.bin','SDS00120.bin','SDS00211.bin','SDS00261.bin','SDS00481.bin']
tfiles = ["DATA/" + x for x in tfiles]
ch1data = []
ch2data = []
ch3data = []
colors = []


# # calculate color of dots based on max/min acceleration
# temp = (acceleration - acceleration.min())/(acceleration.max() - acceleration.min())
# # change values into RGBA array
# color = np.array([[1.0-x,x,0,1] for x in temp])
for i in range(5):
    t1,t2,t = CC.getSmoothData(tfiles[i])
    t3 = t2[1:]-t2[:-1]
    # t3 = t3[:50001]
    t /= 1e-7
    t1 = t1[:-1]
    t2 = t2[:-1]
    v2 = np.array(t3)/1e-7
    ch3data.append(v2[:50001])
    ch1data.append(t1[:50001])
    ch2data.append(t2[:50001])
    temp = v2    
    t = (temp - min(temp))/(max(temp) - min(temp))/2
    tc = np.array([[0.2+x,0.2+x,0.2+x,1] for x in t])
    colors.append(tc[:50001])

# %%
plt.close("all")
plt.figure(figsize=(8,8),dpi=100)
plot = plt.axes(projection="3d")
x = 0
plot.plot3D(ch1data[x],-np.array(ch2data[x]),ch3data[x])
plot.plot3D(ch1data[x+1],-np.array(ch2data[x+1]),ch3data[x+1])
plot.plot3D(ch1data[x+2],-np.array(ch2data[x+2]),ch3data[x+2])
plot.plot3D(ch1data[x+3],-np.array(ch2data[x+3]),ch3data[x+3])
plot.plot3D(ch1data[4],-np.array(ch2data[4]),ch3data[4])
plt.show()

# %%
n = [0,1,2,4]
fig,plts = plt.subplots(nrows=2,ncols=2,tight_layout=1)
fig.set_size_inches((8,8))
fig.set_dpi(100)

plts[0,0].scatter(ch1data[0],-ch2data[0],color=colors[0])
plts[0,0].set_xlim([-0.25,1])
plts[0,0].set_ylim([-0.5,0.75])
plts[0,0].text(-0.2,-0.45,r"$R_v = 50.0~\text{k}\Omega$")
plts[0,0].text(-0.1,0.6,"(a)",size=15)

plts[0,1].scatter(ch1data[1],-ch2data[1],color=colors[1])
plts[0,1].set_xlim([-0.25,1])
plts[0,1].set_ylim([-0.5,0.75])
plts[0,1].text(-0.2,-0.45,r"$R_v = 62.0~\text{k}\Omega$")
plts[0,1].text(-0.1,0.6,"(b)",size=15)

plts[1,0].scatter(ch1data[3],-ch2data[3],color=colors[3])
plts[1,0].set_xlim([-0.25,1])
plts[1,0].set_ylim([-0.5,0.75])
plts[1,0].text(-0.2,-0.45,r"$R_v = 76.0~\text{k}\Omega$")
plts[1,0].text(-0.1,0.6,"(c)",size=15)

plts[1,1].scatter(ch1data[4],-ch2data[4],color=colors[4])
plts[1,1].set_xlim([-0.25,1])
plts[1,1].set_ylim([-0.5,0.75])
plts[1,1].text(-0.2,-0.45,r"$R_v = 98.0~\text{k}\Omega$")
plts[1,1].text(-0.1,0.6,"(d)",size=15)

fig.supylabel(r"$dx/dt$")
fig.supxlabel(r"$x$ ($V$)")

plt.savefig("phasePortraits.pdf",dpi='figure',format='pdf')

plt.show()

# %%
er,edata = CC.unpack("bifurcation.bin")
tr,tdata = CC.unpack("simulated.bin")

# %%
fig,plts = plt.subplots(ncols=1,nrows=2,tight_layout=1)
fig.set_size_inches((5,6))
plts[0].plot(er,edata,'k.',markersize=1.2,alpha=0.5)
plts[0].set_xlim([50,150])
plts[0].set_ylabel(r"$x$ (V)")
plts[0].set_ylim([0,1.5])
plts[0].text(60,1.25,"Experimental")
plts[1].plot(tr,tdata,'k.',markersize=1.2,alpha=0.7)
plts[1].set_xlim([50,150])
plts[1].set_ylabel(r"$x$ (V)")
plts[1].set_ylim([0,1.5])
plts[1].text(60,1.25,"Simulated")
fig.supxlabel(r"$R_v$ (k$\Omega$)")
# plt.figtext(0.05,0.95,"A",size=35,weight="bold")
# plt.savefig("bifurcation.pdf",dpi='figure',format='pdf')
plt.show()

# %% [markdown]
# 70.7k
# 68.3k
# 55.2k

# %%
print(68.3-55.2)
print(70.7-68.3)
# Out:
# 13.099999999999994
# 2.4000000000000057

# %%
# %matplotlib widget

# %%
plt.close('all')
plt.figure(figsize=(16,9),dpi=100)
plt.plot(er,(edata),'k.',markersize=5,alpha=0.5)
plt.grid()
plt.xlim([50,80])
# plt.xticks(np.linspace(50,80,16))
# plt.plot([68.4,68.4],[0,1],'r-')
# plt.plot([55.2,55.2],[0,1],'r-')
# plt.plot([70.7,70.7],[0,1],'r-')
# plt.plot([71.4,71.4],[0,1],'r-')
plt.ylim([0,0.8])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline

# %%
print((np.average([71.56,71.54,71.52,71.42,71.48,71.53,71.39,71.41]))/47)
print((np.average([70.56,70.46,70.66,70.75])+0.1)/47)
print(np.average([68.3,68.22])/47)
print(55.16/47)
# Out:
# 1.5208776595744682
# 1.504414893617021
# 1.4523404255319148
# 1.1736170212765957

# %%
temp = [1.1736170212765957,1.4523404255319148,1.504414893617021,1.5208776595744682]
print((temp[1]-temp[0])/(temp[2]-temp[1]))
print((temp[2]-temp[1])/(temp[3]-temp[2]))
# Out:
# 5.352400408580202
# 3.163166397415094

# %%
print(np.average([3.163166397415094,5.352400408580202]))
# Out:
# 4.257783402997648

# %%
from scipy.signal import find_peaks as fp

# %%
p1 = peaks[1:]
p2 = peaks[2:]
fig,plts = plt.subplots(ncols=1,nrows=2,tight_layout=1)
fig.set_size_inches((5,8))
plts[0].plot(peaks[:-1],p1,'k.',markersize=1.5)
plts[0].plot([0,1],[0,1],'k-')
plts[0].set_xlim([0,1])
plts[0].set_ylim([0,1])
plts[0].set_ylabel(r"$x_{n+1}$ (V)")
plts[0].set_xlabel(r"$x_n$ (V)")
plts[1].plot(peaks[:-2],p2,'k.',markersize=1.5)
plts[1].plot([0,1],[0,1],'k-')
plts[1].set_xlim([0,1])
plts[1].set_ylim([0,1])
plts[1].set_ylabel(r"$x_{n+2}$ (V)")
plts[1].set_xlabel(r"$x_n$ (V)")
# fig.suptitle(r"Return Maps for $R_v=77.4$k$\Omega$")
plt.savefig("returnMap_774.pdf",dpi='figure',format='pdf')
plt.show()
